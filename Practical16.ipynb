# %% [markdown]
# **Practical 16**
# 1. Implement linear regression using Python/R to perform classification on
# Social_Network_Ads.csv dataset.
#
# Sr no. 10th Marks 12th Marks
#    1.      90          80
#    2.      80          90
#    3.      75          75
#    4.      70          65
#    5.      60          70
#
# 2. Find the linear regression for student if he score 78 and 56 in 10th find score they get in 12th exam

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib as plt

# %%
data=pd.read_csv('/content/Social_Network_Ads.csv')
data
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
data['Gender'].replace(['Male','Female'],[0,1],inplace=True)
data
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510       0  19.0          19000.0          0
# 1    15810944       0  35.0          20000.0          0
# 2    15668575       1  26.0          43000.0          0
# 3    15603246       1  27.0          57000.0          0
# 4    15804002       0  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863       1  46.0          41000.0          1
# 396  15706071       0  51.0          23000.0          1
# 397  15654296       1  50.0          20000.0          1
# 398  15755018       0  36.0          33000.0          0
# 399  15594041       1  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
# 1 - Implement linear regression using Python/R to perform classification on Social_Network_Ads.csv dataset.
x=data[["User ID","Gender","Age","EstimatedSalary"]]
y=data["Purchased"]
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size =0.2, random_state = 0)

# %%
print("xtrain shape : ", xtrain.shape)
print("xtest shape  : ", xtest.shape)
print("ytrain shape : ", ytrain.shape)
print("ytest shape  : ", ytest.shape)
# Out:
# xtrain shape :  (320, 4)
# xtest shape  :  (80, 4)
# ytrain shape :  (320,)
# ytest shape  :  (80,)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(xtest)
y_pred
# Out:
# array([ 0.22344052,  0.30461738,  0.29602087,  0.195126  ,  0.22990978,
#        -0.13199155, -0.00461925,  0.60913368, -0.14385071,  0.50988301,
#         0.08200402,  0.03828935,  0.27024252,  0.44422784, -0.04236798,
#         0.38545923,  0.35849632, -0.08369621,  1.05507832,  0.10215531,
#         0.22353931,  0.885951  ,  0.38108705,  0.73155884, -0.16114943,
#         0.92441681,  0.18811886,  0.17558823,  0.32964197,  0.30300205,
#         0.02117823,  0.38943604,  0.79812423,  0.29090075, -0.04310521,
#        -0.22673941,  0.00127591,  0.18739597,  0.0576121 ,  0.54483682,
#         0.14228174,  0.38040762,  0.16363244,  0.07502749,  0.66557994,
#         0.05149858,  0.36923448,  0.80357679, -0.10911261,  0.73081454,
#         1.05264517,  0.10942309,  0.2706367 ,  0.46501231,  1.00282428,
#         0.39283137,  0.18370879,  0.12735288,  0.47092486, -0.20234008,
#         0.03083554,  0.8096761 , -0.11807388,  0.42998934, -0.28113822,
# ...

# %%
# 2 - Find the linear regression for student if he score 78 and 56 in 10th find score they get in 12th exam
from sklearn.linear_model import LinearRegression

X = [[90], [80], [75], [70], [60]]
y = [80, 90, 75, 65, 70]

model = LinearRegression()
model.fit(X, y)

predicted_12th_score_78 = model.predict([[78]])
predicted_12th_score_56 = model.predict([[56]])

print("Predicted 12th grade score for 10th grade score of 78:", predicted_12th_score_78[0])
print("Predicted 12th grade score for 10th grade score of 56:", predicted_12th_score_56[0])
# Out:
# Predicted 12th grade score for 10th grade score of 78: 77.65
# Predicted 12th grade score for 10th grade score of 56: 65.55000000000001

# %% [markdown]
# 2 **Data Wrangling I**
#
# Perform the following operations using Python on dataset(e.g., student.csv)
# 1. Import all the required Python Libraries. And Load the Dataset into pandas data
# frame.
# 2. Data Preprocessing: find the missing values in the data and display statistical
# information.
# 3. Provide variable descriptions. Types of variables etc. Check the dimensions of the
# data frame
# 4. Data Normalization: Perform min max normalization and plot box plot for any
# column
# 5. Turn categorical variables for PG column into quantitative variables in Python.

# %%
# 1 - Import all the required Python Libraries and Load the Dataset into pandas data frame.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/AcademicPerformance_New.csv")
data
# Out:
#     Roll No NationalITy    WT  DSBDA    AI    Average Grade   PG
# 0       1.0       India  72.0   72.0  74.0  72.666667     C  Yes
# 1       2.0       Japan  69.0   90.0   NaN  53.000000     B   No
# 2       NaN         NaN   NaN    NaN   NaN        NaN   NaN  NaN
# 3       4.0       China  47.0    NaN  44.0  30.333333     D  Yes
# 4       5.0       India  76.0   78.0   NaN  51.333333     C   No
# ..      ...         ...   ...    ...   ...        ...   ...  ...
# 94     95.0         USA  79.0    NaN   NaN  26.333333     A   No
# 95     96.0       Japan  78.0   81.0  82.0  80.333333     A   No
# 96     97.0         USA  65.0   66.0  62.0  64.333333     B   No
# 97     98.0      Rassia  63.0   72.0  70.0  68.333333     B  Yes
# 98     99.0       India  58.0   67.0   NaN  41.666667     B   No
#
# [99 rows x 8 columns]

# %%
# 2 - Data Preprocessing: find the missing values in the data and display statistical information.
missing_value = data.isnull().sum()
statistical_info = data.describe()

print("Missing_values: ")
print(missing_value)
print("\nStatistical Information: ")
print(statistical_info)
# Out:
# Missing_values:
# Roll No         1
# NationalITy     1
# WT              8
# DSBDA           4
# AI             10
# Average         1
# Grade           1
# PG              1
# dtype: int64
#
# Statistical Information:
#          Roll No         WT      DSBDA         AI    Average
# count  98.000000  91.000000  95.000000  89.000000  98.000000
# mean   50.479592  61.164835  64.652632  62.235955  58.663265
# std    28.469274  14.995009  14.893072  16.216590  16.518482
# min     1.000000  18.000000  26.000000  20.000000  26.000000
# 25%    26.250000  51.000000  54.500000  52.000000  45.250000
# 50%    50.500000  63.000000  66.000000  63.000000  59.333333
# 75%    74.750000  71.000000  74.000000  74.000000  71.916667
# max    99.000000  97.000000  95.000000  92.000000  91.666667

# %%
# 3 - Provide variable descriptions. Types of variables etc. Check the dimensions of the data frame.
variable_description = {col: f'Description of {col}' for col in data.columns}
print("Variable Description: ")
print(variable_description)
# Out:
# Variable Description:
# {'Roll No': 'Description of Roll No', 'NationalITy': 'Description of NationalITy', 'WT': 'Description of WT', 'DSBDA': 'Description of DSBDA', 'AI': 'Description of AI', 'Average': 'Description of Average', 'Grade': 'Description of Grade', 'PG': 'Description of PG'}

# %%
variable_types = data.dtypes
print("Variable Types: ")
print(variable_types)
# Out:
# Variable Types:
# Roll No        float64
# NationalITy     object
# WT             float64
# DSBDA          float64
# AI             float64
# Average        float64
# Grade           object
# PG              object
# dtype: object

# %%
dimensions = data.shape
print("Dimensions of Data frames: ", dimensions)
# Out:
# Dimensions of Data frames:  (99, 8)

# %%
# 4 - Data Normalization: Perform min max normalization and plot box plot for any column.
x = data[['Average']].values.astype(float)
x
# Out:
#    Roll No NationalITy    WT  DSBDA    AI    Average Grade   PG  \
# 0      1.0       India  72.0   72.0  74.0  72.666667     C  Yes
# 1      2.0       Japan  69.0   90.0   NaN  53.000000     B   No
# 2      NaN         NaN   NaN    NaN   NaN        NaN   NaN  NaN
# 3      4.0       China  47.0    NaN  44.0  30.333333     D  Yes
# 4      5.0       India  76.0   78.0   NaN  51.333333     C   No
#
#    normalized_Average
# 0            0.710660
# 1            0.411168
# 2                 NaN
# 3            0.065990
# 4            0.385787

# %%
from sklearn import preprocessing
min_max_scaler= preprocessing.MinMaxScaler()
x_scale = min_max_scaler.fit_transform(x)
data_normalized = pd.DataFrame(x_scale)
data_normalized

# %%
data[['Average']].max()

# %%
data[['Average']].min()

# %%
data['Average'].plot(kind='box',title='Average of Marks')
plt.show()

# %%
# 5 - Turn categorical variables for PG column into quantitative variables in Python.
data['PG'].replace(['Yes','No'],[0,1],inplace=True)
data
# Out:
#    Roll No NationalITy    WT  DSBDA    AI    Average Grade   PG  \
# 0      1.0       India  72.0   72.0  74.0  72.666667     C  Yes
# 1      2.0       Japan  69.0   90.0   NaN  53.000000     B   No
# 3      4.0       China  47.0    NaN  44.0  30.333333     D  Yes
# 4      5.0       India  76.0   78.0   NaN  51.333333     C   No
# 5      6.0       Japan  71.0   83.0  78.0  77.333333     C  Yes
#
#    normalized_Average  encoded_PG
# 0            0.710660           1
# 1            0.411168           0
# 3            0.065990           1
# 4            0.385787           0
# 5            0.781726           1

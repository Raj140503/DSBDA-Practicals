# %% [markdown]
# 1. **Data Wrangling 1**
#
# Perform the following operations using Python on dataset(e.g., employee.csv)
# 1. Import all the required Python Libraries. And Load the Dataset into pandas data frame.
# 2. Data Preprocessing: find the missing values in the data columnwise and display statistical information.
# 3. Provide variable descriptions. Types of variables etc. Check the dimensions of the data frame
# 4. Data Formatting Summarize the types of variables by checking the data types (i.e.,character, numeric, integer, factor, and logical) of the variables in the data set. If variables are not in the correct data type, apply proper type conversions.
# 5. Data Normalization:Perform Z-Score transformation and plot box plot for any column.
# 6. Turn categorical variables into quantitative variables in Python.

# %%
# 1 - Import all the required Python Libraries. And Load the Dataset into pandas data frame.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 import matplotlib.pyplot as plt
#       5 from scipy.stats import zscore
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
data=pd.read_csv("/content/Employee.csv")

# %%
data
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 0                             0           0
# 1                             3           1
# 2                             2           0
# 3                             5           1
# 4                             2           1
# ...                         ...         ...
# 4648                          4           0
# 4649                          2           1
# 4650                          5           1
# 4651                          2           0
# 4652                          4           0
#
# [4653 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   object
#  1   JoiningYear                4653 non-null   int64
#  2   City                       4653 non-null   object
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   object
#  6   EverBenched                4653 non-null   object
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   LeaveOrNot                 4653 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 327.3+ KB

# %%
data.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
data.tail()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 4648                          4           0
# 4649                          2           1
# 4650                          5           1
# 4651                          2           0
# 4652                          4           0

# %%
data.iloc[11:15]
# Out:
#     Education  JoiningYear       City  PaymentTier  Age Gender EverBenched  \
# 11  Bachelors         2016       Pune            3   34   Male          No
# 12  Bachelors         2018       Pune            3   32   Male         Yes
# 13  Bachelors         2016  Bangalore            3   39   Male          No
# 14  Bachelors         2012  Bangalore            3   37   Male          No
#
#     ExperienceInCurrentDomain  LeaveOrNot
# 11                          3           0
# 12                          5           1
# 13                          2           0
# 14                          4           0

# %%
# 2 - Data Preprocessing: find the missing values in the data columnwise and display statistical information.

# %%
missing_value = data.isnull().sum()

# %%
statistical_info = data.describe()

# %%
print("Missing Values:")
print(missing_value)
print("\nStatistical_Information:")
print(statistical_info)
# Out:
# Missing Values:
# Education                    0
# JoiningYear                  0
# City                         0
# PaymentTier                  0
# Age                          0
# Gender                       0
# EverBenched                  0
# ExperienceInCurrentDomain    0
# LeaveOrNot                   0
# dtype: int64
#
# Statistical_Information:
#        JoiningYear  PaymentTier          Age  ExperienceInCurrentDomain  \
# count  4653.000000  4653.000000  4653.000000                4653.000000
# mean   2015.062970     2.698259    29.393295                   2.905652
# std       1.863377     0.561435     4.826087                   1.558240
# min    2012.000000     1.000000    22.000000                   0.000000
# 25%    2013.000000     3.000000    26.000000                   2.000000
# 50%    2015.000000     3.000000    28.000000                   3.000000
# 75%    2017.000000     3.000000    32.000000                   4.000000
# max    2018.000000     3.000000    41.000000                   7.000000
#
#         LeaveOrNot
# count  4653.000000
# mean      0.343864
# std       0.475047
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
# 3 - Provide variable descriptions. Types of variables etc. Check the dimensions of the data frame.
variable_descriptions = {col: f'Description of {col}' for col in data.columns}
print("Variable Descriptions")
print(variable_descriptions)
# Out:
# Variable Descriptions
# {'Education': 'Description of Education', 'JoiningYear': 'Description of JoiningYear', 'City': 'Description of City', 'PaymentTier': 'Description of PaymentTier', 'Age': 'Description of Age', 'Gender': 'Description of Gender', 'EverBenched': 'Description of EverBenched', 'ExperienceInCurrentDomain': 'Description of ExperienceInCurrentDomain', 'LeaveOrNot': 'Description of LeaveOrNot'}

# %%
variable_types = data.dtypes
print("Variable Types: ")
print(variable_types)
# Out:
# Variable Types:
# Education                    object
# JoiningYear                   int64
# City                         object
# PaymentTier                   int64
# Age                           int64
# Gender                       object
# EverBenched                  object
# ExperienceInCurrentDomain     int64
# LeaveOrNot                    int64
# dtype: object

# %%
dimensions = data.shape
print("Dimensions of Dataframe: ", dimensions)
# Out:
# Dimensions of Dataframe:  (4653, 9)

# %%
# 4 - Data Formatting Summarize the types of variables by checking the data types (i.e.,character, numeric, integer, factor, and logical) of the variables in the data set. If variables are not in the correct data type, apply proper type conversions.
data["JoiningYear"] = data["JoiningYear"].astype('int64')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   object
#  1   JoiningYear                4653 non-null   int64
#  2   City                       4653 non-null   object
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   object
#  6   EverBenched                4653 non-null   object
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   LeaveOrNot                 4653 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 327.3+ KB

# %%
# 5 - Data Normalization: Perform Z-Score transformation and plot box plot for any column.
column_name = 'JoiningYear'
data['Z-Scores'] = zscore(data[column_name])
print(data.head())
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot  Z-Scores
# 0                          0           0  1.039638
# 1                          3           1 -1.107233
# 2                          2           0 -0.570515
# 3                          5           1  0.502921
# 4                          2           1  1.039638

# %%
data['JoiningYear'].plot(kind='box',title='Joining Year of Employee')
plt.show()

# %%
# 6 - Turn categorical variables into quantitative variables in Python.
data["Gender"].replace(['Male','Female'],[0,1],inplace=True)
data["Education"].replace(['Bachelors','Masters'],[0,1],inplace=True)
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data["Gender"].replace(['Male','Female'],[0,1],inplace=True)
#       2 data["Education"].replace(['Bachelors','Masters'],[0,1],inplace=True)
#       3 data
#
# NameError: name 'data' is not defined
